# %%
import pandas as pd

# Step 1: Data Ingestion 
df = pd.read_csv('spotify_history.csv')

# %%
df
# Out:
#              spotify_track_uri                   ts    platform  ms_played  \
# 0       2J3n32GeLmMjwuAzyhcSNe  2013-07-08 02:44:34  web player       3185
# 1       1oHxIPqJyvAYHy0PVrDU98  2013-07-08 02:45:37  web player      61865
# 2       487OPlneJNni3NWC8SYqhW  2013-07-08 02:50:24  web player     285386
# 3       5IyblF777jLZj1vGHG2UD3  2013-07-08 02:52:40  web player     134022
# 4       0GgAAB0ZMllFhbNc3mAodO  2013-07-08 03:17:52  web player          0
# ...                        ...                  ...         ...        ...
# 149855  4Fz1WWr5o0OrlIcZxcyZtK  2024-12-15 23:06:19     android       1247
# 149856  0qHMhBZqYb99yhX9BHcIkV  2024-12-15 23:06:21     android       1515
# 149857  0HHdujGjOZChTrl8lJWEIq  2024-12-15 23:06:22     android       1283
# 149858  7peh6LUcdNPcMdrSH4JPsM  2024-12-15 23:06:23     android       1306
# 149859  6iGU74CwXuT4XVepjc9Emf  2024-12-15 23:06:25     android       1893
#
# ...

# %%
#drop duplicates
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 149855    False
# 149856    False
# 149857    False
# 149858    False
# 149859    False
# Length: 149860, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 1185

# %%
df.drop_duplicates()
# Out:
#              spotify_track_uri                   ts    platform  ms_played  \
# 0       2J3n32GeLmMjwuAzyhcSNe  2013-07-08 02:44:34  web player       3185
# 1       1oHxIPqJyvAYHy0PVrDU98  2013-07-08 02:45:37  web player      61865
# 2       487OPlneJNni3NWC8SYqhW  2013-07-08 02:50:24  web player     285386
# 3       5IyblF777jLZj1vGHG2UD3  2013-07-08 02:52:40  web player     134022
# 4       0GgAAB0ZMllFhbNc3mAodO  2013-07-08 03:17:52  web player          0
# ...                        ...                  ...         ...        ...
# 149855  4Fz1WWr5o0OrlIcZxcyZtK  2024-12-15 23:06:19     android       1247
# 149856  0qHMhBZqYb99yhX9BHcIkV  2024-12-15 23:06:21     android       1515
# 149857  0HHdujGjOZChTrl8lJWEIq  2024-12-15 23:06:22     android       1283
# 149858  7peh6LUcdNPcMdrSH4JPsM  2024-12-15 23:06:23     android       1306
# 149859  6iGU74CwXuT4XVepjc9Emf  2024-12-15 23:06:25     android       1893
#
# ...

# %%
# Step 3: Handle Missing Values
df['reason_start'].fillna('unknown', inplace=True)
df['reason_end'].fillna('unknown', inplace=True)
df
# Out:
#              spotify_track_uri                   ts    platform  ms_played  \
# 0       2J3n32GeLmMjwuAzyhcSNe  2013-07-08 02:44:34  web player       3185
# 1       1oHxIPqJyvAYHy0PVrDU98  2013-07-08 02:45:37  web player      61865
# 2       487OPlneJNni3NWC8SYqhW  2013-07-08 02:50:24  web player     285386
# 3       5IyblF777jLZj1vGHG2UD3  2013-07-08 02:52:40  web player     134022
# 4       0GgAAB0ZMllFhbNc3mAodO  2013-07-08 03:17:52  web player          0
# ...                        ...                  ...         ...        ...
# 149855  4Fz1WWr5o0OrlIcZxcyZtK  2024-12-15 23:06:19     android       1247
# 149856  0qHMhBZqYb99yhX9BHcIkV  2024-12-15 23:06:21     android       1515
# 149857  0HHdujGjOZChTrl8lJWEIq  2024-12-15 23:06:22     android       1283
# 149858  7peh6LUcdNPcMdrSH4JPsM  2024-12-15 23:06:23     android       1306
# 149859  6iGU74CwXuT4XVepjc9Emf  2024-12-15 23:06:25     android       1893
#
# ...

# %%
df
# Out:
#              spotify_track_uri                   ts    platform  ms_played  \
# 0       2J3n32GeLmMjwuAzyhcSNe  2013-07-08 02:44:34  web player       3185
# 1       1oHxIPqJyvAYHy0PVrDU98  2013-07-08 02:45:37  web player      61865
# 2       487OPlneJNni3NWC8SYqhW  2013-07-08 02:50:24  web player     285386
# 3       5IyblF777jLZj1vGHG2UD3  2013-07-08 02:52:40  web player     134022
# 4       0GgAAB0ZMllFhbNc3mAodO  2013-07-08 03:17:52  web player          0
# ...                        ...                  ...         ...        ...
# 149855  4Fz1WWr5o0OrlIcZxcyZtK  2024-12-15 23:06:19     android       1247
# 149856  0qHMhBZqYb99yhX9BHcIkV  2024-12-15 23:06:21     android       1515
# 149857  0HHdujGjOZChTrl8lJWEIq  2024-12-15 23:06:22     android       1283
# 149858  7peh6LUcdNPcMdrSH4JPsM  2024-12-15 23:06:23     android       1306
# 149859  6iGU74CwXuT4XVepjc9Emf  2024-12-15 23:06:25     android       1893
#
# ...

# %%
#rename
df.rename(columns={'ts':'Timestamp','ms_played':'Duration_ms','track_name': 'track',
    'artist_name': 'artist',
    'album_name': 'album',
    'reason_start': 'start_reason',
    'reason_end': 'end_reason'},inplace=True)

# %%
df
# Out:
#              spotify_track_uri            Timestamp    platform  Duration_ms  \
# 0       2J3n32GeLmMjwuAzyhcSNe  2013-07-08 02:44:34  web player         3185
# 1       1oHxIPqJyvAYHy0PVrDU98  2013-07-08 02:45:37  web player        61865
# 2       487OPlneJNni3NWC8SYqhW  2013-07-08 02:50:24  web player       285386
# 3       5IyblF777jLZj1vGHG2UD3  2013-07-08 02:52:40  web player       134022
# 4       0GgAAB0ZMllFhbNc3mAodO  2013-07-08 03:17:52  web player            0
# ...                        ...                  ...         ...          ...
# 149855  4Fz1WWr5o0OrlIcZxcyZtK  2024-12-15 23:06:19     android         1247
# 149856  0qHMhBZqYb99yhX9BHcIkV  2024-12-15 23:06:21     android         1515
# 149857  0HHdujGjOZChTrl8lJWEIq  2024-12-15 23:06:22     android         1283
# 149858  7peh6LUcdNPcMdrSH4JPsM  2024-12-15 23:06:23     android         1306
# 149859  6iGU74CwXuT4XVepjc9Emf  2024-12-15 23:06:25     android         1893
#
# ...

# %%
#data type correction
df['Timestamp']=pd.to_datetime(df['Timestamp'])

# %%
df
# Out:
#              spotify_track_uri           Timestamp    platform  Duration_ms  \
# 0       2J3n32GeLmMjwuAzyhcSNe 2013-07-08 02:44:34  web player         3185
# 1       1oHxIPqJyvAYHy0PVrDU98 2013-07-08 02:45:37  web player        61865
# 2       487OPlneJNni3NWC8SYqhW 2013-07-08 02:50:24  web player       285386
# 3       5IyblF777jLZj1vGHG2UD3 2013-07-08 02:52:40  web player       134022
# 4       0GgAAB0ZMllFhbNc3mAodO 2013-07-08 03:17:52  web player            0
# ...                        ...                 ...         ...          ...
# 149855  4Fz1WWr5o0OrlIcZxcyZtK 2024-12-15 23:06:19     android         1247
# 149856  0qHMhBZqYb99yhX9BHcIkV 2024-12-15 23:06:21     android         1515
# 149857  0HHdujGjOZChTrl8lJWEIq 2024-12-15 23:06:22     android         1283
# 149858  7peh6LUcdNPcMdrSH4JPsM 2024-12-15 23:06:23     android         1306
# 149859  6iGU74CwXuT4XVepjc9Emf 2024-12-15 23:06:25     android         1893
#
# ...

# %%
df[df['Timestamp']>'2023-11-01']
# Out:
#              spotify_track_uri           Timestamp platform  Duration_ms  \
# 138430  4xaPCPyMiFDiw7SoksTBKo 2023-11-01 02:08:15  android       358533
# 138431  2WFlUh3vI3duc27xe7miox 2023-11-01 02:11:57  android       221226
# 138432  0FQLQfuCKSlcVSOPscqCJ6 2023-11-01 02:22:12  android       614266
# 138433  1lIcdDpGlc2mO2LYA0f5KM 2023-11-01 02:34:30  android       738080
# 138434  6caCfb9Hg5NlUfXg9nRSnm 2023-11-01 02:42:05  android       454520
# ...                        ...                 ...      ...          ...
# 149855  4Fz1WWr5o0OrlIcZxcyZtK 2024-12-15 23:06:19  android         1247
# 149856  0qHMhBZqYb99yhX9BHcIkV 2024-12-15 23:06:21  android         1515
# 149857  0HHdujGjOZChTrl8lJWEIq 2024-12-15 23:06:22  android         1283
# 149858  7peh6LUcdNPcMdrSH4JPsM 2024-12-15 23:06:23  android         1306
# 149859  6iGU74CwXuT4XVepjc9Emf 2024-12-15 23:06:25  android         1893
#
#                                                     track          artist  \
# ...

# %%
df['2024'] = df['Timestamp'].dt.year
#extracting year
df
# Out:
#              spotify_track_uri           Timestamp    platform  Duration_ms  \
# 0       2J3n32GeLmMjwuAzyhcSNe 2013-07-08 02:44:34  web player         3185
# 1       1oHxIPqJyvAYHy0PVrDU98 2013-07-08 02:45:37  web player        61865
# 2       487OPlneJNni3NWC8SYqhW 2013-07-08 02:50:24  web player       285386
# 3       5IyblF777jLZj1vGHG2UD3 2013-07-08 02:52:40  web player       134022
# 4       0GgAAB0ZMllFhbNc3mAodO 2013-07-08 03:17:52  web player            0
# ...                        ...                 ...         ...          ...
# 149855  4Fz1WWr5o0OrlIcZxcyZtK 2024-12-15 23:06:19     android         1247
# 149856  0qHMhBZqYb99yhX9BHcIkV 2024-12-15 23:06:21     android         1515
# 149857  0HHdujGjOZChTrl8lJWEIq 2024-12-15 23:06:22     android         1283
# 149858  7peh6LUcdNPcMdrSH4JPsM 2024-12-15 23:06:23     android         1306
# 149859  6iGU74CwXuT4XVepjc9Emf 2024-12-15 23:06:25     android         1893
#
# ...

# %%
# Format Standardization
text_columns = ['platform', 'track', 'artist', 'album', 'start_reason', 'end_reason']
for col in text_columns:
    df[col] = df[col].astype(str).str.strip().str.upper()

# %%
df
# Out:
#              spotify_track_uri           Timestamp    platform  Duration_ms  \
# 0       2J3n32GeLmMjwuAzyhcSNe 2013-07-08 02:44:34  WEB PLAYER         3185
# 1       1oHxIPqJyvAYHy0PVrDU98 2013-07-08 02:45:37  WEB PLAYER        61865
# 2       487OPlneJNni3NWC8SYqhW 2013-07-08 02:50:24  WEB PLAYER       285386
# 3       5IyblF777jLZj1vGHG2UD3 2013-07-08 02:52:40  WEB PLAYER       134022
# 4       0GgAAB0ZMllFhbNc3mAodO 2013-07-08 03:17:52  WEB PLAYER            0
# ...                        ...                 ...         ...          ...
# 149855  4Fz1WWr5o0OrlIcZxcyZtK 2024-12-15 23:06:19     ANDROID         1247
# 149856  0qHMhBZqYb99yhX9BHcIkV 2024-12-15 23:06:21     ANDROID         1515
# 149857  0HHdujGjOZChTrl8lJWEIq 2024-12-15 23:06:22     ANDROID         1283
# 149858  7peh6LUcdNPcMdrSH4JPsM 2024-12-15 23:06:23     ANDROID         1306
# 149859  6iGU74CwXuT4XVepjc9Emf 2024-12-15 23:06:25     ANDROID         1893
#
# ...

# %%
df.to_csv('cleaned_spotify_history.csv', index=False)

# %%
print("Cleaned Data ")
print(df.info)
print()
